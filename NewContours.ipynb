# %%
# import darkplotter lib
import darkplotter as dp
import sys

# %% [markdown]
# ## Data class constructor

# %%
A=dp.DMdata()

# %%
url='https://raw.githubusercontent.com/odadoun/DarkPlotter/main/json/SI-CDMS-CDMS%20Si-b1519fe1d0d66e576bc7e5400a5709f0.json'
A.uploadexperiement(url=url)

# %%
A.get_pandas()
# Out:
#            parameters-space collaboration                        label  \
# experiment
# CDMS Si                  SI          CDMS  CDMS II Si, c58, 140.2 kg-d
#
#                                                       comment  \
# experiment
# CDMS Si     CDMS II c58 Si official limit. Published in PR...
#
#                       arxiv                             doi  \
# experiment
# CDMS Si     arXiv:1304.4279  10.1103/PhysRevLett.111.251301
#
#                                                        bibtex category  shape  \
# experiment
# CDMS Si     @article{PhysRevLett.111.251301,title = {Silic...    Limit  curve
#
#            x-units y-units                                                  x  \
# experiment
# CDMS Si        GeV    cm^2  [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
#
#                                                             y
# experiment
# CDMS Si     [1.1268999999999999e-39, 5.5005e-40, 3.1455999...

# %% [markdown]
# ## Get metadata

# %%
A.get_metadata()
# Out:
#            parameters-space collaboration                        label  \
# experiment
# CDMS Si                  SI          CDMS  CDMS II Si, c58, 140.2 kg-d
#
#                                                       comment  \
# experiment
# CDMS Si     CDMS II c58 Si official limit. Published in PR...
#
#                       arxiv                             doi  \
# experiment
# CDMS Si     arXiv:1304.4279  10.1103/PhysRevLett.111.251301
#
#                                                        bibtex category  shape  \
# experiment
# CDMS Si     @article{PhysRevLett.111.251301,title = {Silic...    Limit  curve
#
#            x-units y-units
# experiment
# CDMS Si        GeV    cm^2

# %% [markdown]
# ## Data information

# %%
A.get_data()
# Out:
#                                                             x  \
# experiment
# CDMS Si     [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
#
#                                                             y
# experiment
# CDMS Si     [1.1268999999999999e-39, 5.5005e-40, 3.1455999...

# %% [markdown]
# ## Add an other experiment

# %%
url2='https://raw.githubusercontent.com/odadoun/DarkPlotter/main/json/SI-EDELWEISS-EDELWEISS-LM%20Migdal-ad6d0d92325506725b809f7e157477db.json'
path="/Users/dadoun/Desktop/DarkMatter/DarkPlotter/json/SI-XENON-XENON1T-12723871358400c0c3ee60732374d3c9.json"
A.uploadexperiement(url=url2)

# %%
A.get_pandas()
# Out:
#                     parameters-space collaboration  \
# experiment
# CDMS Si                           SI          CDMS
# EDELWEISS-LM Migdal               SI     EDELWEISS
#
#                                            label  \
# experiment
# CDMS Si              CDMS II Si, c58, 140.2 kg-d
# EDELWEISS-LM Migdal          EDELWEISS-LM Migdal
#
#                                                                comment  \
# experiment
# CDMS Si              CDMS II c58 Si official limit. Published in PR...
# EDELWEISS-LM Migdal  Migdal limits from a small above ground detect...
#
#                                                 arxiv  \
# experiment
# CDMS Si                               arXiv:1304.4279
# EDELWEISS-LM Migdal  https://arxiv.org/abs/1901.03588
#
#                                                             doi  \
# experiment
# CDMS Si                          10.1103/PhysRevLett.111.251301
# EDELWEISS-LM Migdal  https://doi.org/10.1103/PhysRevD.99.082003
#
#                                                                 bibtex  \
# experiment
# CDMS Si              @article{PhysRevLett.111.251301,title = {Silic...
# EDELWEISS-LM Migdal  @article{Armengaud_2019, title={Searching for ...
#
#                     category  shape x-units y-units  \
# experiment
# CDMS Si                Limit  curve     GeV    cm^2
# EDELWEISS-LM Migdal    Limit  curve     GeV    cm^2
#
#                                                                      x  \
# experiment
# CDMS Si              [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
# EDELWEISS-LM Migdal  [0.045, 0.044950000000000004, 0.0471, 0.053250...
#
#                                                                      y
# experiment
# CDMS Si              [1.1268999999999999e-39, 5.5005e-40, 3.1455999...
# EDELWEISS-LM Migdal  [4.5460000000000005e-27, 3.5079999999999997e-2...

# %%
A.get_data()
# Out:
#                                                                      x  \
# experiment
# CDMS Si              [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
# EDELWEISS-LM Migdal  [0.045, 0.044950000000000004, 0.0471, 0.053250...
#
#                                                                      y
# experiment
# CDMS Si              [1.1268999999999999e-39, 5.5005e-40, 3.1455999...
# EDELWEISS-LM Migdal  [4.5460000000000005e-27, 3.5079999999999997e-2...

# %% [markdown]
# ## Plot constructor

# %%
B=dp.DMplotter()

# %%
A.get_data()
# Out:
#                                                                      x  \
# experiment
# CDMS Si              [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
# EDELWEISS-LM Migdal  [0.045, 0.044950000000000004, 0.0471, 0.053250...
#
#                                                                      y
# experiment
# CDMS Si              [1.1268999999999999e-39, 5.5005e-40, 3.1455999...
# EDELWEISS-LM Migdal  [4.5460000000000005e-27, 3.5079999999999997e-2...

# %%
#Make the plot and choose the x axis by setting Mev, GeV or TeV, default unit is GeV
#C=A.get_experiment()
C=A.get_experiment(collaboration=["CDMS","EDELWEISS"])
C.set_index("experiment")
B.plot(C,massunit="GeV")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2020\1698928179.py in <module>
#       3 C=A.get_experiment(collaboration=["CDMS","EDELWEISS"])
#       4 C.set_index("experiment")
# ----> 5 B.plot(C,massunit="GeV")
#
# \\span\profiles\wangjing\デスクトップ\Axion\Xelab\DarkPlotter\darkplotter.py in plot(self, mypandas, massunit)
#     163                                      min(ymin,focus.y.min()), max(ymax,focus.y.max())
#     164             self.figlimits = {'xmin':xmin, 'xmax':xmax, 'ymin':ymin, 'ymax':ymax}
# --> 165         self.draw(lineplots,massunit)
#     166         #self.draw(allplots,massunit)
#     167
#
# \\span\profiles\wangjing\デスクトップ\Axion\Xelab\DarkPlotter\darkplotter.py in draw(self, dico, massunit)
#     191             }
#     192         """)
# --> 193         labels = LabelSet(x=10,y=1e-30, text='test',x_offset=0, y_offset=0, source=dico, render_mode='canvas')
#     194         checkbox.js_on_change('active', callback)
#     195         curdoc().theme = Theme(filename="./theme.yml")
#
# c:\Users\wangjing\.conda\envs\xelab\lib\site-packages\bokeh\model\model.py in __init__(self, **kwargs)
#     126         kwargs.pop("id", None)
#     127
# --> 128         super().__init__(**kwargs)
#     129         default_theme.apply_to_model(self)
#     130
#
# c:\Users\wangjing\.conda\envs\xelab\lib\site-packages\bokeh\core\has_props.py in __init__(self, **properties)
#     204
#     205         for name, value in properties.items():
# --> 206             setattr(self, name, value)
#     207
#     208         self._initialized = True
#
# c:\Users\wangjing\.conda\envs\xelab\lib\site-packages\bokeh\core\has_props.py in __setattr__(self, name, value)
#     228         properties = self.properties(_with_props=True)
#     229         if name in properties:
# --> 230             return super().__setattr__(name, value)
#     231
#     232         descriptor = getattr(self.__class__, name, None)
#
# c:\Users\wangjing\.conda\envs\xelab\lib\site-packages\bokeh\core\property\descriptors.py in __set__(self, obj, value, setter)
#     281             raise RuntimeError(f"{class_name}.{self.name} is a readonly property")
#     282
# --> 283         value = self.property.prepare_value(obj, self.name, value)
#     284         old = self._get(obj)
#     285         self._set(obj, old, value, setter=setter)
#
# c:\Users\wangjing\.conda\envs\xelab\lib\site-packages\bokeh\core\property\bases.py in prepare_value(self, owner, name, value, hint)
#     363         else:
#     364             obj_repr = owner if isinstance(owner, HasProps) else owner.__name__
# --> 365             raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
#     366
#     367         if isinstance(owner, HasProps):
#
# ValueError: failed to validate LabelSet(id='1056', ...).source: expected an instance of type DataSource, got {'CDMS Si': GlyphRenderer(id='1040', ...), 'EDELWEISS-LM Migdal': GlyphRenderer(id='1047', ...)} of type dict

# %% [markdown]
# ## A folder with experiement json can be loaded
# by defautl this folder
# https://github.com/odadoun/DarkPlotter/tree/NewGraphicToAdd/json/
# A conversion between github file path and rawgithub need to be done

# %%
# retrieve url

# %%
u=A.githubpath2raw()

# %%
AA=dp.DMdata()
AA.uploadexperiement(url=u.rawurl.tolist())

# %%
#Select experiments by setting "collaboration" and "experiment", no parameter will plot all the experiments
#Examples for different cases
#C=AA.get_experiment()
#C=AA.get_experiment(collaboration=["CDMS","XENON"],experiment=["SuperCDMS","XENON1T"])
#C=AA.get_experiment(collaboration=["COSINE"])
#C=AA.get_experiment(collaboration=["DAMA"])
C=AA.get_experiment(collaboration=["CDMS","XENON"])
#C=AA.get_experiment(experiment=["SuperCDMS","XENON1T"])
#C=AA.get_experiment(experiment=["Null"])
#C.set_index("collaboration")

# %%
B.plot(C,massunit="GeV")
# Out:
#   <div class="bk-root" id="8760045c-96a2-49b0-a31e-14ced04949ae" data-root-id="1135"></div>
