# %%
# import darkplotter lib
import darkplotter as dp
import sys

# %% [markdown]
# ## Data class constructor

# %%
A=dp.DMdata()

# %%
url='https://raw.githubusercontent.com/odadoun/DarkPlotter/main/json/SI-CDMS-CDMS%20Si-b1519fe1d0d66e576bc7e5400a5709f0.json'
A.uploadexperiement(url=url)

# %%
A.get_pandas()
# Out:
#            parameters-space collaboration                        label  \
# experiment
# CDMS Si                  SI          CDMS  CDMS II Si, c58, 140.2 kg-d
#
#                                                       comment  \
# experiment
# CDMS Si     CDMS II c58 Si official limit. Published in PR...
#
#                       arxiv                             doi  \
# experiment
# CDMS Si     arXiv:1304.4279  10.1103/PhysRevLett.111.251301
#
#                                                        bibtex category  shape  \
# experiment
# CDMS Si     @article{PhysRevLett.111.251301,title = {Silic...    Limit  curve
#
#            x-units y-units                                                  x  \
# experiment
# CDMS Si        GeV    cm^2  [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
#
#                                                             y
# experiment
# CDMS Si     [1.1268999999999999e-39, 5.5005e-40, 3.1455999...

# %% [markdown]
# ## Get metadata

# %%
A.get_metadata()
# Out:
#            parameters-space collaboration                        label  \
# experiment
# CDMS Si                  SI          CDMS  CDMS II Si, c58, 140.2 kg-d
#
#                                                       comment  \
# experiment
# CDMS Si     CDMS II c58 Si official limit. Published in PR...
#
#                       arxiv                             doi  \
# experiment
# CDMS Si     arXiv:1304.4279  10.1103/PhysRevLett.111.251301
#
#                                                        bibtex category  shape  \
# experiment
# CDMS Si     @article{PhysRevLett.111.251301,title = {Silic...    Limit  curve
#
#            x-units y-units
# experiment
# CDMS Si        GeV    cm^2

# %% [markdown]
# ## Data information

# %%
A.get_data()
# Out:
#                                                             x  \
# experiment
# CDMS Si     [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
#
#                                                             y
# experiment
# CDMS Si     [1.1268999999999999e-39, 5.5005e-40, 3.1455999...

# %% [markdown]
# ## Add an other experiment

# %%
url2='https://raw.githubusercontent.com/odadoun/DarkPlotter/main/json/SI-EDELWEISS-EDELWEISS-LM%20Migdal-ad6d0d92325506725b809f7e157477db.json'
path="/Users/dadoun/Desktop/DarkMatter/DarkPlotter/json/SI-XENON-XENON1T-12723871358400c0c3ee60732374d3c9.json"
A.uploadexperiement(url=url2)

# %%
A.get_pandas()
# Out:
#                     parameters-space collaboration  \
# experiment
# CDMS Si                           SI          CDMS
# EDELWEISS-LM Migdal               SI     EDELWEISS
#
#                                            label  \
# experiment
# CDMS Si              CDMS II Si, c58, 140.2 kg-d
# EDELWEISS-LM Migdal          EDELWEISS-LM Migdal
#
#                                                                comment  \
# experiment
# CDMS Si              CDMS II c58 Si official limit. Published in PR...
# EDELWEISS-LM Migdal  Migdal limits from a small above ground detect...
#
#                                                 arxiv  \
# experiment
# CDMS Si                               arXiv:1304.4279
# EDELWEISS-LM Migdal  https://arxiv.org/abs/1901.03588
#
#                                                             doi  \
# experiment
# CDMS Si                          10.1103/PhysRevLett.111.251301
# EDELWEISS-LM Migdal  https://doi.org/10.1103/PhysRevD.99.082003
#
#                                                                 bibtex  \
# experiment
# CDMS Si              @article{PhysRevLett.111.251301,title = {Silic...
# EDELWEISS-LM Migdal  @article{Armengaud_2019, title={Searching for ...
#
#                     category  shape x-units y-units  \
# experiment
# CDMS Si                Limit  curve     GeV    cm^2
# EDELWEISS-LM Migdal    Limit  curve     GeV    cm^2
#
#                                                                      x  \
# experiment
# CDMS Si              [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
# EDELWEISS-LM Migdal  [0.045, 0.044950000000000004, 0.0471, 0.053250...
#
#                                                                      y
# experiment
# CDMS Si              [1.1268999999999999e-39, 5.5005e-40, 3.1455999...
# EDELWEISS-LM Migdal  [4.5460000000000005e-27, 3.5079999999999997e-2...

# %%
A.get_data()
# Out:
#                                                                      x  \
# experiment
# CDMS Si              [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
# EDELWEISS-LM Migdal  [0.045, 0.044950000000000004, 0.0471, 0.053250...
#
#                                                                      y
# experiment
# CDMS Si              [1.1268999999999999e-39, 5.5005e-40, 3.1455999...
# EDELWEISS-LM Migdal  [4.5460000000000005e-27, 3.5079999999999997e-2...

# %% [markdown]
# ## Plot constructor

# %%
B=dp.DMplotter()

# %%
A.get_data()
# Out:
#                                                                      x  \
# experiment
# CDMS Si              [5.5488, 5.9238, 6.3241, 6.7531, 7.2094, 7.696...
# EDELWEISS-LM Migdal  [0.045, 0.044950000000000004, 0.0471, 0.053250...
#
#                                                                      y
# experiment
# CDMS Si              [1.1268999999999999e-39, 5.5005e-40, 3.1455999...
# EDELWEISS-LM Migdal  [4.5460000000000005e-27, 3.5079999999999997e-2...

# %%
#Make the plot and choose the x axis by setting Mev, GeV or TeV, default unit is GeV
#C=A.get_experiment()
C=A.get_experiment(collaboration=["CDMS","EDELWEISS"])
C.set_index("experiment")
B.plot(C,massunit="TeV")
# Out:
#   <div class="bk-root" id="d4c50266-9420-4eb8-93fb-3ecb8e2bf582" data-root-id="1002"></div>

# %% [markdown]
# ## A folder with experiement json can be loaded
# by defautl this folder
# https://github.com/odadoun/DarkPlotter/tree/NewGraphicToAdd/json/
# A conversion between github file path and rawgithub need to be done

# %%
# retrieve url

# %%
u=A.githubpath2raw()

# %%
AA=dp.DMdata()
AA.uploadexperiement(url=u.rawurl.tolist())

# %%
#Select experiments by setting "collaboration" and "experiment", no parameter will plot all the experiments
#Examples for different cases
# C=AA.get_experiment()
C=AA.get_experiment(collaboration=["CDMS","XENON"],experiment=["SuperCDMS","XENON1T"])
#C=AA.get_experiment(collaboration=["CDMS","XENON"])
#C=AA.get_experiment(experiment=["SuperCDMS","XENON1T"])
#C=AA.get_experiment(experiment=["Null"])
C.set_index("collaboration")
# Out:
#               parameters-space              experiment  \
# collaboration
# CDMS                        SI            SuperCDMS HT
# CDMS                        SI            SuperCDMS LT
# CDMS                        SI           SuperCDMS-CPD
# XENON                       SI  XENON1T Bremsstrahlung
# XENON                       SI          XENON1T Migdal
# XENON                       SI                 XENON1T
#
#                                               label  \
# collaboration
# CDMS                    SuperCDMS iZIP HT, (90% CL)
# CDMS                  SuperCDMS Soudan LT, (90% CL)
# CDMS                                  SuperCDMS-CPD
# XENON          XENON1T, Bremsstrahlung, 22 ton-days
# XENON                  XENON1T, Migdal, 22 ton-days
# XENON                          XENON1T, 22 ton-days
#
#                                                     comment  \
# collaboration
# CDMS                                           HT PRL limit
# CDMS                          90% C.L. WIMP exclusion limit
# CDMS           SuperCDMS-CPD Limit at SLAC Surface Facility
# XENON                                  Xenon1T 2019 results
# XENON                                  Xenon1T 2019 results
# XENON                                  Xenon1T 2019 results
#
#                                           arxiv  \
# collaboration
# CDMS
# CDMS                            arXiv:1402.7137
# CDMS                           arXiv:2007.14289
# XENON          https://arxiv.org/abs/1907.12771
# XENON          https://arxiv.org/abs/1907.12771
# XENON          https://arxiv.org/abs/1907.11485
#
#                                                           doi  \
# collaboration
# CDMS
# CDMS                                   PhysRevLett.112.241302
# CDMS                           10.1103/PhysRevLett.127.061801
# XENON          https://doi.org/10.1103/PhysRevLett.123.241803
# XENON          https://doi.org/10.1103/PhysRevLett.123.241803
# XENON          https://doi.org/10.1103/PhysRevLett.123.251801
#
#                                                           bibtex category  \
# collaboration
# CDMS                                                         NaN    Limit
# CDMS           @article{PhysRevLett.112.241302, title = {Sear...    Limit
# CDMS           @article{Alkhatib_2021, title={Light Dark Matt...    Limit
# XENON          @article{aprile2019search, title={A Search for...    Limit
# XENON          @article{aprile2019search, title={A Search for...    Limit
# XENON          @article{Aprile_2019, title={Light Dark Matter...    Limit
#
#                shape x-units y-units  \
# collaboration
# CDMS           curve     GeV    cm^2
# CDMS           curve     GeV    cm^2
# CDMS           curve     GeV    cm^2
# XENON          curve     GeV    cm^2
# XENON          curve     GeV    cm^2
# XENON          curve     GeV    cm^2
#
#                                                                x  \
# collaboration
# CDMS           [5.5517179715600005, 5.62483218162, 5.69890928...
# CDMS           [2.891, 3.029, 3.175, 3.327, 3.485999999999999...
# CDMS           [1.5, 1.399, 1.306, 1.218, 1.1360000000000001,...
# XENON          [0.51, 0.53, 0.55, 0.6000000000000001, 0.65, 0...
# XENON          [0.11, 0.12, 0.13, 0.14, 0.2, 0.5, 0.55, 0.56,...
# XENON          [2.73, 2.75, 2.8, 3.0, 3.2, 3.5, 3.7, 4.0, 4.2...
#
#                                                                y
# collaboration
# CDMS           [1.3987010885e-31, 2.39444151574e-34, 2.088607...
# CDMS           [1.3459e-36, 8.7596e-38, 1.6686e-38, 4.2168999...
# CDMS           [1.8639999999999998e-36, 1.827e-36, 1.78299999...
# XENON          [1.91965123773912e-32, 1.4276298960002002e-32,...
# XENON          [2.80297860981593e-35, 1.39005928999398e-35, 7...
# XENON          [9.288431945297945e-40, 6.319272619037611e-40,...

# %%
B.plot(C,massunit="GeV")
# Out:
#   <div class="bk-root" id="911f6b70-9d56-46f5-9f51-e2f3e149f709" data-root-id="1135"></div>
