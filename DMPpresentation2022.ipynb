# %% [markdown]
# <img src="images/DeathStar.png" alt="FAIRE" style="width: 400px;"/>
#
# <h1><center>The Dark Matter Plotter </center></h1>
# Olivier Dadoun dadoun@in2p3.fr LPNHE october 2022 Nantes

# %% [markdown]
# ## Foreword
# A lot of materials (idea, images ...) have been taken in the HUGE documentation concerning
# OpenScience available on the web. Please have a look onto the blibliography at the end of the notebook

# %% [markdown]
# <h1><center> Motivation</center></h1>
# $\bullet$ One can define the open science as a collaborative culture enabled by technology that allow the open sharing of data, information, and knowledge within the scientific community
# and the wider public to accelerate scientific research and understanding
#
# $\bullet$ As science has become increasingly data driven, data programs now play a critical role in enabling and accelerating open science.

# %% [markdown]
# <img src="images/Jupyterlogo.png" alt="FAIRE" style="width: 200px;"/>
# $\bullet$ Jupyter notebooks helps data scientists to combine code, explanatory text and multimedia resources in one document.
# $\bullet$ Jupyter notebooks make science more visual and easily understandable.
#
# $\bullet$ Jupyter notebooks make scientific collaboration easier
#
# $\bullet$  Jupyter notebooks can work as gate-opener for general public

# %% [markdown]
# <img src="images/FAIRsymbols.jpg" alt="FAIRE" style="width: 200px;"/>
#
# # $\bullet$ FAIR data
# ## data which meet principles of findability, accessibility, interoperability, and reusability
#
# $\bullet$ Findable
#
# The first step in (re)using data is to find them
# Metadata and data should be easy to find for both humans and computers
#
# $\bullet$ Accessible
#
# Once the user finds the required data, they need to know how they can be accessed
#
# $\bullet$ Interoperable
#
# The data usually need to be integrated with other data.
#
# $\bullet$ Reusable
#
# The ultimate goal of FAIR is to optimise the reuse of data. To achieve this, metadata and data s
#
# <img src="images/fairdata.png" alt="FAIRE" style="width: 800px;"/>

# %% [markdown]
# <img src="images/bokeh.png" alt="FAIRE" style="width: 200px;"/>
#
# ## Bokeh
#
# Bokeh is a Python visualization library for large datasets that natively uses the latest web technologies.
#
#
# $\bullet$ easily create novel and powerful visualizations
# $\bullet$    that extract insight from remote, possibly large data sets
# $\bullet$    published to the web for others to explore and interact

# %% [markdown]
# ## Open science has become a pillar in the research world
#
# ## A web site to drop new data (from experiment/simulation)
# ## A code to explore and plot the data

# %% [markdown]
# # Data packaging
# Data packages are containers for describing and sharing accompanying data files,
# and typically comprise a metadata file describing the features and context of a dataset.
# This can include aspects such as creation information, provenance, size, format type, field definitions,
# as well
# as any relevant contextual files, such as data creation scripts or textual documentation
#
# ## The Public
#
# The general public may not be interested in using the data*,
# but they are interested in seeing the results. Without the work from the other interested parties,
# the public does not have anything to view except the raw data.
#
# Counterexample: abviouly it depends on the data see #covid19 data and the lot of public dashboard released  counterexample.
# By the way let me make some advertasing for my covid19 Python analysis project: pycoa.fr

# %%
# import darkplotter lib
import darkplotter as dp

# %%
# constructor
A=dp.DMplotter()

# %%
url1='https://raw.githubusercontent.com/odadoun/DarkPlotter/main/WIMPLimits/SDn/AllLimits-2021.txt'
u1=A.getdata(url=url1)
url2='https://raw.githubusercontent.com/odadoun/DarkPlotter/main/WIMPLimits/SDn/CDMS.txt'
u2=A.getdata(url=url2)
u3=A.getdata()

# %%
u3
# Out:
#                exp                                                  x  \
# 0   AllLimits-2018  [2.2787, 2.3252, 2.3726, 2.421, 2.4703, 2.5207...
# 1   AllLimits-2021  [2.2787, 2.2979105081705065, 2.317282969921637...
# 2            COUPP  [3.981, 4.365, 4.786, 5.248, 5.754, 6.31, 6.91...
# 3       IceCube-tt  [20.115, 33.024, 96.54, 236.02, 482.54, 994.6,...
# 4             KIMS  [20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90....
# 5          PICASSO  [2.2787, 2.5784, 3.0157, 3.3848, 3.9591, 4.866...
# 6           PICO2L  [3.3113, 3.6308, 3.9811, 4.3652, 4.7863, 5.248...
# 7           PICO60  [3.8992, 3.9263, 4.0646, 4.15, 4.2962, 4.4475,...
# 8        SuperK-tt  [4.0015, 6.0267, 10.057, 19.691, 49.701, 99.33...
# 9          XENON1T  [6.012029853720273, 6.327396227085619, 6.73713...
# 10       nufloor-F  [0.1, 0.10116, 0.10233, 0.10352, 0.10472, 0.10...
# 11      nufloor-Xe  [0.1, 0.10116, 0.10233, 0.10352, 0.10472, 0.10...
#
#                                                     y
# 0   [2.9338e-37, 2.7492e-37, 2.5609e-37, 2.3687e-3...
# 1   [2.9337999999999847e-37, 2.8318597446823967e-3...
# 2   [1.5399999999999999e-34, 2.1570000000000001e-3...
# 3   [7.4757e-40, 1.8107999999999998e-40, 3.7445e-4...
# 4   [1.3259e-37, 3.824e-38, 2.3539e-38, 1.9045e-38...
# 5   [2.9338e-37, 1.7433e-37, 1.0731e-37, 8.0206999...
# 6   [8.5638e-33, 5.4104e-36, 5.6411e-37, 1.3643e-3...
# 7   [9.710299999999999e-38, 6.3267e-38, 3.6768e-38...
# 8   [2.2464999999999996e-40, 1.636e-40, 1.34179999...
# 9   [1.1391568751828702e-37, 7.236091901764883e-38...
# 10  [5.143570082223117e-43, 5.2634378483103126e-43...
# 11  [7.473010247971518e-39, 7.662302584384722e-39,...

# %%
A.plot([u1,u2])
# Out:
#   <div class="bk-root" id="8ea8c724-93f0-42ec-ba63-c6efd779720a" data-root-id="1002"></div>

# %% [markdown]
# ## Motivation

# %% [markdown]
# $\bullet$ Provide an online tool to draw exclusion plots of DM experiments for the community
# $\bullet$ Using a JSON standard file one can push on a github
#
# $\bullet$ DarkMatter experiments should provides their data for

# %% [markdown]
# #Bibliography
# ## From Open Data to Open Science,  Rahul Ramachandran1& al. (NASA)
#
# https://agupubs.onlinelibrary.wiley.com/doi/epdf/10.1029/2020EA001562
#
# ## The Open Science Training Handbook
#
# https://open-science-training-handbook.gitbook.io/book/open-science-basics/open-research-data-and-materials
